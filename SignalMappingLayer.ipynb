# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import callbacks
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Flatten, Dense, Input, MaxPooling2D
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import os

# %%
BASE_DIR = "Scans"  # ganti sesuai foldermu
OUTPUT_NPY = "latent_rep/final_dataset_baru.npy"

# %%
print("TensorFlow version:", tf.__version__)
print("Built with CUDA:", tf.test.is_built_with_cuda())
print("GPU available:", tf.config.list_physical_devices('GPU'))
# Out:
# TensorFlow version: 2.10.1
# Built with CUDA: True
# GPU available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
print("Physical GPUs:", tf.config.list_physical_devices("GPU"))
print("Logical GPUs:", tf.config.list_logical_devices("GPU"))
# Out:
# Physical GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Logical GPUs: [LogicalDevice(name='/device:GPU:0', device_type='GPU')]

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %% [markdown]
# # All The Functions

# %%
def load_and_stack_scans(base_dir, output_file="latent_rep/final_dataset_baru.npy", verbose=True):
    all_scans = []

    for i in range(1, 716):
        folder = f'Scan{i}'
        folder_path = os.path.join(base_dir, folder)

        if not os.path.exists(folder_path) or len(os.listdir(folder_path)) == 0:
            if verbose:
                print(f"⚠️ Skipping {folder} (missing or empty)")
            continue

        mag_file = os.path.join(folder_path, f"magnitude{i}_normalized.csv")
        phase_file = os.path.join(folder_path, f"phase{i}.csv")

        if not os.path.isfile(mag_file) or not os.path.isfile(phase_file):
            if verbose:
                print(f"⚠️ Skipping {folder} (missing CSV files)")
            continue

        mag = pd.read_csv(mag_file, header=None, skiprows=1).values
        phase = pd.read_csv(phase_file, header=None, skiprows=1).values

        if mag.shape != (24, 24) or phase.shape != (24, 24):
            if verbose:
                print(f"⚠️ Shape mismatch in {folder}: mag {mag.shape}, phase {phase.shape}")
            continue

        mag = np.expand_dims(mag, axis=-1)
        phase = np.expand_dims(phase, axis=-1)
        combined = np.concatenate([mag, phase], axis=-1)
        all_scans.append(combined)

    dataset = np.stack(all_scans, axis=0)
    np.save(output_file, dataset)

    if verbose:
        print(f"✅ Total valid scans collected: {len(all_scans)}")
        print(f"💾 Dataset saved! Shape: {dataset.shape}")

    return dataset

# %%
def data_preparation():
    # Load dataset
    X_signal = np.load("latent_rep/final_dataset_baru.npy")  # shape (N, 24,24,2)
    # latent_rep = np.load("latent_rep/latent_all.npy")        # shape (N, latent_dim)

    # N = X_signal.shape[0]
    # indices = np.arange(N)

    # Split: train/test
    # train_idx, temp_idx = train_test_split(indices, test_size=0.3, random_state=42)
    # # Split temp_idx menjadi val/test dengan presisi
    # val_idx, test_idx = train_test_split(temp_idx, test_size=108, random_state=42)  # 108 val, 107 test

    # Ambil data sesuai indeks, urutan tetap sama
    X_signal_train = X_signal[:500]
    X_signal_val   = X_signal[500:608]
    X_signal_test  = X_signal[608:]

    latent_train = np.load('latent_rep/latent_train.npy')
    latent_val   = np.load('latent_rep/latent_val.npy')
    latent_test  = np.load('latent_rep/latent_test.npy')

    # Normalisasi latent
    scaler = StandardScaler()
    latent_train = scaler.fit_transform(latent_train)
    latent_val   = scaler.transform(latent_val)
    latent_test  = scaler.transform(latent_test)
    latent_rep = {'train': latent_train, 'val': latent_val, 'test': latent_test}

    # X_signal_train[..., 0] /= X_signal_train[..., 0].max()
    # X_signal_val[..., 0]   /= X_signal_train[..., 0].max() 
    # X_signal_test[..., 0]  /= X_signal_train[..., 0].max()

    # Phase channel
    # X_signal_train[..., 1] /= np.pi
    # X_signal_val[..., 1]   /= np.pi
    # X_signal_test[..., 1]  /= np.pi
    X_signal = {'train': X_signal_train, 'val': X_signal_val, 'test': X_signal_test}

    input_shape = X_signal_train.shape[1:]
    latent_dim  = latent_train.shape[1]

    return latent_rep, X_signal, input_shape, latent_dim

# %%
def create_cnn(input_shape, latent_dim):
  model = Sequential([
    Input(shape=input_shape),         # (24,24,2)
    Conv2D(16,(3,3),activation='relu'),
    MaxPooling2D((2,2)),
    Conv2D(32,(3,3),activation='relu'),
    MaxPooling2D((2,2)),
    Conv2D(64,(3,3),activation='relu'),
    Flatten(),
    Dense(512,activation='relu',kernel_regularizer=tf.keras.regularizers.L2(0.001)),
    Dense(256,activation='relu'),   # sebelum latent
    Dense(latent_dim,activation='linear')  # latent_dim=256
  ])
  return model

# %%
def build_and_train_model(input_shape, latent_dim, latent_rep, X_signal):
  model = create_cnn(input_shape, latent_dim)
  model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
                loss="mean_squared_error",
                metrics=["mean_squared_error"])

  lr_callback = callbacks.LearningRateScheduler(lambda epoch, lr: lr * 0.1 if epoch > 30 else lr)
  early_stopping = callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
  tensorboard_callback = callbacks.TensorBoard(log_dir="./logs", histogram_freq=1)
  model_checkpoint = callbacks.ModelCheckpoint("model/sml_checkpoint.keras", save_best_only=True, monitor='val_loss')

  callbacks_list = [lr_callback, early_stopping, tensorboard_callback, model_checkpoint]

  # Train the model
  with tf.device('/GPU:0'):
      history = model.fit(
          X_signal['train'], latent_rep['train'],
          validation_data=(X_signal['val'], latent_rep['val']),
          epochs=30,
          batch_size=2,
          callbacks=callbacks_list
      )

  model.save("model/sml_final_model.keras")
  return history, model

# %%
def evaluate_model(model, signal_test, latent_test):
  test_loss = model.evaluate(signal_test, latent_test, batch_size=2)
  print(f"Test Loss (MSE): {test_loss}")

# %%
def visualize_training(history):
  plt.plot(history.history['mean_squared_error'], label='Training Loss')
  plt.plot(history.history['val_mean_squared_error'], label='Validation Loss')
  plt.title('Model Loss')
  plt.xlabel('Epochs')
  plt.ylabel('Loss (MSE)')
  plt.legend()
  plt.show()

# %%
def pipeline():
  latent_file_path = os.path.join('latent_rep', 'final_dataset_baru.npy')
  # convert_xlsx_to_csv(BASE_DIR)

  if not os.path.exists(latent_file_path):
    print(f"{latent_file_path} not found. Running load_and_stack_scans().")
    load_and_stack_scans(BASE_DIR)
  else:
    print(f'{latent_file_path} exists. Proceed to next steps')
    
  latent_rep, X_signal, input_shape, latent_dim = data_preparation()
  history, model_final = build_and_train_model(input_shape, latent_dim, latent_rep, X_signal)
  evaluate_model(model_final, X_signal['test'], latent_rep['test'])
  visualize_training(history)
  # print("Train X:", X_signal['train'].shape)
  # print("Train Y:", latent_rep['train'].shape)
  # print("Val X:", X_signal['val'].shape)
  # print("Val Y:", latent_rep['val'].shape)
  # print("Test X:", X_signal['test'].shape)
  # print("Test Y:", latent_rep['test'].shape)

# %% [markdown]
# # Implementation

# %%
pipeline()
# Out:
# latent_rep\final_dataset_baru.npy exists. Proceed to next steps
# Epoch 1/30
# 250/250 [==============================] - 1s 3ms/step - loss: 0.7842 - mean_squared_error: 0.7166 - val_loss: 0.7285 - val_mean_squared_error: 0.7184 - lr: 0.0010
# Epoch 2/30
# 250/250 [==============================] - 1s 2ms/step - loss: 0.7050 - mean_squared_error: 0.6999 - val_loss: 0.7422 - val_mean_squared_error: 0.7389 - lr: 0.0010
# Epoch 3/30
# 250/250 [==============================] - 1s 2ms/step - loss: 0.6560 - mean_squared_error: 0.6531 - val_loss: 0.6558 - val_mean_squared_error: 0.6536 - lr: 0.0010
# Epoch 4/30
# 250/250 [==============================] - 1s 2ms/step - loss: 0.6314 - mean_squared_error: 0.6295 - val_loss: 0.6437 - val_mean_squared_error: 0.6421 - lr: 0.0010
# Epoch 5/30
# 250/250 [==============================] - 1s 2ms/step - loss: 0.6247 - mean_squared_error: 0.6232 - val_loss: 0.6354 - val_mean_squared_error: 0.6340 - lr: 0.0010
# Epoch 6/30
# 250/250 [==============================] - 1s 2ms/step - loss: 0.6161 - mean_squared_error: 0.6147 - val_loss: 0.6469 - val_mean_squared_error: 0.6455 - lr: 0.0010
# Epoch 7/30
# 250/250 [==============================] - 1s 2ms/step - loss: 0.6121 - mean_squared_error: 0.6108 - val_loss: 0.6553 - val_mean_squared_error: 0.6541 - lr: 0.0010
# Epoch 8/30
# 250/250 [==============================] - 1s 2ms/step - loss: 0.6051 - mean_squared_error: 0.6037 - val_loss: 0.6341 - val_mean_squared_error: 0.6326 - lr: 0.0010
# Epoch 9/30
# 250/250 [==============================] - 1s 2ms/step - loss: 0.6016 - mean_squared_error: 0.6000 - val_loss: 0.6414 - val_mean_squared_error: 0.6397 - lr: 0.0010
# Epoch 10/30
# 250/250 [==============================] - 1s 2ms/step - loss: 0.5894 - mean_squared_error: 0.5875 - val_loss: 0.6430 - val_mean_squared_error: 0.6411 - lr: 0.0010
# Epoch 11/30
# 250/250 [==============================] - 1s 2ms/step - loss: 0.5856 - mean_squared_error: 0.5834 - val_loss: 0.6507 - val_mean_squared_error: 0.6484 - lr: 0.0010
# Epoch 12/30
# 250/250 [==============================] - 1s 2ms/step - loss: 0.5754 - mean_squared_error: 0.5725 - val_loss: 0.6417 - val_mean_squared_error: 0.6383 - lr: 0.0010
# Epoch 13/30
# 250/250 [==============================] - 1s 2ms/step - loss: 0.5646 - mean_squared_error: 0.5607 - val_loss: 0.6629 - val_mean_squared_error: 0.6587 - lr: 0.0010
# Epoch 14/30
# 250/250 [==============================] - 1s 2ms/step - loss: 0.5465 - mean_squared_error: 0.5425 - val_loss: 0.6642 - val_mean_squared_error: 0.6605 - lr: 0.0010
# Epoch 15/30
# 250/250 [==============================] - 1s 2ms/step - loss: 0.5401 - mean_squared_error: 0.5361 - val_loss: 0.6259 - val_mean_squared_error: 0.6221 - lr: 0.0010
# Epoch 16/30
# 250/250 [==============================] - 1s 2ms/step - loss: 0.5166 - mean_squared_error: 0.5127 - val_loss: 0.6363 - val_mean_squared_error: 0.6324 - lr: 0.0010
# Epoch 17/30
# 250/250 [==============================] - 1s 2ms/step - loss: 0.5047 - mean_squared_error: 0.5006 - val_loss: 0.6491 - val_mean_squared_error: 0.6448 - lr: 0.0010
# Epoch 18/30
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4952 - mean_squared_error: 0.4906 - val_loss: 0.6736 - val_mean_squared_error: 0.6689 - lr: 0.0010
# Epoch 19/30
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4797 - mean_squared_error: 0.4749 - val_loss: 0.6848 - val_mean_squared_error: 0.6796 - lr: 0.0010
# Epoch 20/30
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4728 - mean_squared_error: 0.4674 - val_loss: 0.6580 - val_mean_squared_error: 0.6522 - lr: 0.0010
# Epoch 21/30
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4590 - mean_squared_error: 0.4533 - val_loss: 0.6852 - val_mean_squared_error: 0.6793 - lr: 0.0010
# Epoch 22/30
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4391 - mean_squared_error: 0.4329 - val_loss: 0.6547 - val_mean_squared_error: 0.6482 - lr: 0.0010
# Epoch 23/30
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4278 - mean_squared_error: 0.4211 - val_loss: 0.6981 - val_mean_squared_error: 0.6910 - lr: 0.0010
# Epoch 24/30
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4133 - mean_squared_error: 0.4060 - val_loss: 0.6911 - val_mean_squared_error: 0.6835 - lr: 0.0010
# Epoch 25/30
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4039 - mean_squared_error: 0.3961 - val_loss: 0.6624 - val_mean_squared_error: 0.6544 - lr: 0.0010
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5732 - mean_squared_error: 0.5694
# Test Loss (MSE): [0.5732043385505676, 0.5693661570549011]
