# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import callbacks
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Flatten, Dense, Input, MaxPooling2D
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import matplotlib.pyplot as plt
import os

# %%
BASE_DIR = "Scans - New"  # ganti sesuai foldermu
OUTPUT_NPY = "latent_rep/final_dataset_baru.npy"

# %%
print("TensorFlow version:", tf.__version__)
print("Built with CUDA:", tf.test.is_built_with_cuda())
print("GPU available:", tf.config.list_physical_devices('GPU'))
# Out:
# TensorFlow version: 2.10.1
# Built with CUDA: True
# GPU available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
print("Physical GPUs:", tf.config.list_physical_devices("GPU"))
print("Logical GPUs:", tf.config.list_logical_devices("GPU"))
# Out:
# Physical GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Logical GPUs: [LogicalDevice(name='/device:GPU:0', device_type='GPU')]

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %% [markdown]
# # All The Functions

# %%
def load_and_stack_scans(base_dir, output_file="latent_rep/final_dataset_baru.npy", verbose=True):
    all_scans = []

    for i in range(1, 716):
        folder = f'Scan{i}'
        folder_path = os.path.join(base_dir, folder)

        if not os.path.exists(folder_path) or len(os.listdir(folder_path)) == 0:
            if verbose:
                print(f"⚠️ Skipping {folder} (missing or empty)")
            continue

        mag_file = os.path.join(folder_path, f"magnitude{i}_normalized.csv")
        phase_file = os.path.join(folder_path, f"phase{i}_normalized.csv")

        if not os.path.isfile(mag_file) or not os.path.isfile(phase_file):
            if verbose:
                print(f"⚠️ Skipping {folder} (missing CSV files)")
            continue

        mag = pd.read_csv(mag_file, header=None).values
        phase = pd.read_csv(phase_file, header=None).values

        if mag.shape != (24, 24) or phase.shape != (24, 24):
            if verbose:
                print(f"⚠️ Shape mismatch in {folder}: mag {mag.shape}, phase {phase.shape}")
            continue

        mag = np.expand_dims(mag, axis=-1)
        phase = np.expand_dims(phase, axis=-1)
        combined = np.concatenate([mag, phase], axis=-1)
        all_scans.append(combined)

    dataset = np.stack(all_scans, axis=0)
    np.save(output_file, dataset)

    if verbose:
        print(f"✅ Total valid scans collected: {len(all_scans)}")
        print(f"💾 Dataset saved! Shape: {dataset.shape}")

    return dataset

# %%
def data_preparation():
    # Load dataset
    X_signal = np.load("latent_rep/final_dataset_baru.npy")  # shape (N, 24,24,2)
    latent_rep = np.load("latent_rep/latent_all.npy")        # shape (N, latent_dim)

    N = X_signal.shape[0]
    indices = np.arange(N)

    # Split: train/test
    train_idx, temp_idx = train_test_split(indices, test_size=0.3, random_state=42)
    # Split temp_idx menjadi val/test dengan presisi
    val_idx, test_idx = train_test_split(temp_idx, test_size=107, random_state=42)  # 108 val, 107 test

    # Ambil data sesuai indeks, urutan tetap sama
    # X_signal_train = X_signal[:500]
    # X_signal_val   = X_signal[500:608]
    # X_signal_test  = X_signal[608:]

    latent_train = np.load('latent_rep/latent_train.npy')
    latent_val   = np.load('latent_rep/latent_val.npy')
    latent_test  = np.load('latent_rep/latent_test.npy')

    # Normalisasi latent
    scaler = MinMaxScaler()
    latent_train = scaler.fit_transform(latent_train)
    latent_val   = scaler.transform(latent_val)
    latent_test  = scaler.transform(latent_test)
    latent_rep = {'train': latent_train, 'val': latent_val, 'test': latent_test}
    
    X_signal_train = X_signal[train_idx]
    X_signal_val   = X_signal[val_idx]
    X_signal_test  = X_signal[test_idx]
    X_signal = {'train': X_signal_train, 'val': X_signal_val, 'test': X_signal_test}

    input_shape = X_signal_train.shape[1:]
    latent_dim  = latent_train.shape[1]

    return latent_rep, X_signal, input_shape, latent_dim

# %%
def create_cnn(input_shape, latent_dim):
  model = Sequential([
    Input(shape=input_shape),         # (24,24,2)
    Conv2D(16,(3,3),activation='relu'),
    MaxPooling2D((2,2)),
    Conv2D(32,(3,3),activation='relu'),
    MaxPooling2D((2,2)),
    Conv2D(64,(3,3),activation='relu'),
    Flatten(),
    Dense(512,activation='relu',kernel_regularizer=tf.keras.regularizers.L2(0.001)),
    Dense(256,activation='relu'),   # sebelum latent
    Dense(latent_dim,activation='linear')  # latent_dim=256
  ])
  return model

# %%
def build_and_train_model(input_shape, latent_dim, latent_rep, X_signal):
  model = create_cnn(input_shape, latent_dim)
  model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
                loss="mean_squared_error",
                metrics=["mean_squared_error"])

  lr_callback = callbacks.LearningRateScheduler(lambda epoch, lr: lr * 0.1 if epoch > 30 else lr)
  early_stopping = callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
  tensorboard_callback = callbacks.TensorBoard(log_dir="./logs", histogram_freq=1)
  model_checkpoint = callbacks.ModelCheckpoint("model/sml_checkpoint.keras", save_best_only=True, monitor='val_loss')

  callbacks_list = [lr_callback, early_stopping, tensorboard_callback, model_checkpoint]

  # Train the model
  with tf.device('/GPU:0'):
      history = model.fit(
          X_signal['train'], latent_rep['train'],
          validation_data=(X_signal['val'], latent_rep['val']),
          epochs=30,
          batch_size=2,
          callbacks=callbacks_list
      )

  model.save("model/sml_final_model.keras")
  return history, model

# %%
def evaluate_model(model, signal_test, latent_test):
  test_loss = model.evaluate(signal_test, latent_test, batch_size=2)
  print(f"Test Loss (MSE): {test_loss}")

# %%
def visualize_training(history):
  plt.plot(history.history['mean_squared_error'], label='Training Loss')
  plt.plot(history.history['val_mean_squared_error'], label='Validation Loss')
  plt.title('Model Loss')
  plt.xlabel('Epochs')
  plt.ylabel('Loss (MSE)')
  plt.legend()
  plt.show()

# %%
def pipeline():
  latent_file_path = os.path.join('latent_rep', 'final_dataset_baru.npy')
  # convert_xlsx_to_csv(BASE_DIR)

  if not os.path.exists(latent_file_path):
    print(f"{latent_file_path} not found. Running load_and_stack_scans().")
    load_and_stack_scans(BASE_DIR)
  else:
    print(f'{latent_file_path} exists. Proceed to next steps')
    
  latent_rep, X_signal, input_shape, latent_dim = data_preparation()
  history, model_final = build_and_train_model(input_shape, latent_dim, latent_rep, X_signal)
  evaluate_model(model_final, X_signal['test'], latent_rep['test'])
  visualize_training(history)
  # print("Train X:", X_signal['train'].shape)
  # print("Train Y:", latent_rep['train'].shape)
  # print("Val X:", X_signal['val'].shape)
  # print("Val Y:", latent_rep['val'].shape)
  # print("Test X:", X_signal['test'].shape)
  # print("Test Y:", latent_rep['test'].shape)

# %% [markdown]
# # Implementation

# %%
pipeline()
# Out:
# latent_rep\final_dataset_baru.npy exists. Proceed to next steps
# Epoch 1/30
# 250/250 [==============================] - 1s 3ms/step - loss: 0.0716 - mean_squared_error: 0.0303 - val_loss: 0.0486 - val_mean_squared_error: 0.0479 - lr: 0.0010
# Epoch 2/30
# 250/250 [==============================] - 1s 2ms/step - loss: 0.0276 - mean_squared_error: 0.0271 - val_loss: 0.0467 - val_mean_squared_error: 0.0464 - lr: 0.0010
# Epoch 3/30
# 250/250 [==============================] - 1s 2ms/step - loss: 0.0257 - mean_squared_error: 0.0254 - val_loss: 0.0459 - val_mean_squared_error: 0.0456 - lr: 0.0010
# Epoch 4/30
# 250/250 [==============================] - 1s 2ms/step - loss: 0.0251 - mean_squared_error: 0.0249 - val_loss: 0.0455 - val_mean_squared_error: 0.0453 - lr: 0.0010
# Epoch 5/30
# 250/250 [==============================] - 1s 2ms/step - loss: 0.0247 - mean_squared_error: 0.0244 - val_loss: 0.0450 - val_mean_squared_error: 0.0448 - lr: 0.0010
# Epoch 6/30
# 250/250 [==============================] - 1s 2ms/step - loss: 0.0242 - mean_squared_error: 0.0240 - val_loss: 0.0446 - val_mean_squared_error: 0.0444 - lr: 0.0010
# Epoch 7/30
# 250/250 [==============================] - 1s 2ms/step - loss: 0.0238 - mean_squared_error: 0.0236 - val_loss: 0.0446 - val_mean_squared_error: 0.0444 - lr: 0.0010
# Epoch 8/30
# 250/250 [==============================] - 1s 2ms/step - loss: 0.0235 - mean_squared_error: 0.0233 - val_loss: 0.0444 - val_mean_squared_error: 0.0442 - lr: 0.0010
# Epoch 9/30
# 250/250 [==============================] - 0s 2ms/step - loss: 0.0235 - mean_squared_error: 0.0233 - val_loss: 0.0457 - val_mean_squared_error: 0.0455 - lr: 0.0010
# Epoch 10/30
# 250/250 [==============================] - 1s 2ms/step - loss: 0.0227 - mean_squared_error: 0.0225 - val_loss: 0.0446 - val_mean_squared_error: 0.0444 - lr: 0.0010
# Epoch 11/30
# 250/250 [==============================] - 1s 2ms/step - loss: 0.0225 - mean_squared_error: 0.0223 - val_loss: 0.0443 - val_mean_squared_error: 0.0441 - lr: 0.0010
# Epoch 12/30
# 250/250 [==============================] - 1s 2ms/step - loss: 0.0222 - mean_squared_error: 0.0220 - val_loss: 0.0448 - val_mean_squared_error: 0.0445 - lr: 0.0010
# Epoch 13/30
# 250/250 [==============================] - 1s 2ms/step - loss: 0.0219 - mean_squared_error: 0.0217 - val_loss: 0.0446 - val_mean_squared_error: 0.0443 - lr: 0.0010
# Epoch 14/30
# 250/250 [==============================] - 1s 2ms/step - loss: 0.0214 - mean_squared_error: 0.0211 - val_loss: 0.0441 - val_mean_squared_error: 0.0438 - lr: 0.0010
# Epoch 15/30
# 250/250 [==============================] - 1s 2ms/step - loss: 0.0207 - mean_squared_error: 0.0203 - val_loss: 0.0441 - val_mean_squared_error: 0.0438 - lr: 0.0010
# Epoch 16/30
# 250/250 [==============================] - 1s 2ms/step - loss: 0.0206 - mean_squared_error: 0.0203 - val_loss: 0.0437 - val_mean_squared_error: 0.0434 - lr: 0.0010
# Epoch 17/30
# 250/250 [==============================] - 1s 2ms/step - loss: 0.0198 - mean_squared_error: 0.0195 - val_loss: 0.0442 - val_mean_squared_error: 0.0439 - lr: 0.0010
# Epoch 18/30
# 250/250 [==============================] - 1s 2ms/step - loss: 0.0197 - mean_squared_error: 0.0194 - val_loss: 0.0450 - val_mean_squared_error: 0.0447 - lr: 0.0010
# Epoch 19/30
# 250/250 [==============================] - 1s 2ms/step - loss: 0.0194 - mean_squared_error: 0.0191 - val_loss: 0.0449 - val_mean_squared_error: 0.0446 - lr: 0.0010
# Epoch 20/30
# 250/250 [==============================] - 1s 2ms/step - loss: 0.0190 - mean_squared_error: 0.0187 - val_loss: 0.0446 - val_mean_squared_error: 0.0443 - lr: 0.0010
# Epoch 21/30
# 250/250 [==============================] - 0s 2ms/step - loss: 0.0186 - mean_squared_error: 0.0183 - val_loss: 0.0459 - val_mean_squared_error: 0.0456 - lr: 0.0010
# Epoch 22/30
# 250/250 [==============================] - 1s 2ms/step - loss: 0.0187 - mean_squared_error: 0.0184 - val_loss: 0.0453 - val_mean_squared_error: 0.0450 - lr: 0.0010
# Epoch 23/30
# 250/250 [==============================] - 1s 2ms/step - loss: 0.0182 - mean_squared_error: 0.0179 - val_loss: 0.0448 - val_mean_squared_error: 0.0445 - lr: 0.0010
# Epoch 24/30
# 250/250 [==============================] - 0s 2ms/step - loss: 0.0177 - mean_squared_error: 0.0174 - val_loss: 0.0454 - val_mean_squared_error: 0.0451 - lr: 0.0010
# Epoch 25/30
# 250/250 [==============================] - 0s 2ms/step - loss: 0.0178 - mean_squared_error: 0.0174 - val_loss: 0.0454 - val_mean_squared_error: 0.0450 - lr: 0.0010
# Epoch 26/30
# 250/250 [==============================] - 0s 2ms/step - loss: 0.0172 - mean_squared_error: 0.0169 - val_loss: 0.0460 - val_mean_squared_error: 0.0457 - lr: 0.0010
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0266 - mean_squared_error: 0.0263
# Test Loss (MSE): [0.026622094213962555, 0.026297662407159805]
